# %%
"""
1. predict patient nodule
"""

import torch
from utils.config import Config
from utils.message import Msg
from utils.validation import Validation, get_cube, combine_image
from net.ResUnet import ResNetUNet
from utils.save import Save
from utils.convert import Convert
from utils.visualization import show_views
import segmentation_models_pytorch as smp
from net.baseNet import UNet_3d
from utils.crop import get_crop_info
from data.BasisDataset import BaseDataset
import numpy as np


msg = Msg()
config = Config()
validation = Validation()
convert_file = Convert()
save = Save()

# model = UNet(n_channels=1, classes=2)
config.first_model = f"./ResNetUNet_sec_False_Adam_0/CP_epoch11.pth"
# model = smp.Unet('resnet34', encoder_weights='imagenet', classes=2,in_channels=1)
model1 = ResNetUNet(in_channel=1, classes=4)
model1.load_state_dict(torch.load(config.first_model,
                                  map_location=config.device))
model1.to(device=config.device)

# raw image root
image_root = "/public/home/cxiao/Study/data/kits21/image/4/case_00277.nii.gz"
mask_root = "/public/home/cxiao/Study/data/kits21/mask/4/case_00277.nii.gz"
# xcd fix
patient_name = ""
images_numpy, spacing = convert_file.select(image_root)
ground_t,spacing = convert_file.select(mask_root)

# nodule segment
# masks = validation.predict_all(model, images_numpy, config)
print(images_numpy.shape)
#     images_numpy =np.expand_dims(images_numpy, axis=1)
first_masks = validation.predict_all(model1, BaseDataset.preprocess(images_numpy), config)
# save
show_views(images_numpy[39], ground_t[39], first_masks[39], cmap="gray")
msg.norm("masks len", len(first_masks))
msg.norm("masks len", first_masks.shape)
# Out:
# (128, 256, 256)
# INFO: masks len:128
# INFO: masks len:torch.Size([128, 256, 256])

# %%
index = 34

show_views(images_numpy[index], ground_t[index], first_masks[index], cmap="gray")

# %%
crop_info = get_crop_info(images_numpy,first_masks)
print(torch.from_numpy(images_numpy).shape, first_masks.shape)
print(crop_info)
# Out:
# torch.Size([128, 256, 256]) torch.Size([128, 256, 256])
# [{'slice': 24, 'patch_count': 0, 'bbox': [50, 306, 36, 292]}, {'slice': 25, 'patch_count': 0, 'bbox': [50, 306, 36, 292]}, {'slice': 26, 'patch_count': 0, 'bbox': [56, 312, 43, 299]}, {'slice': 27, 'patch_count': 0, 'bbox': [55, 311, 43, 299]}, {'slice': 28, 'patch_count': 0, 'bbox': [55, 311, 43, 299]}, {'slice': 29, 'patch_count': 0, 'bbox': [55, 311, 45, 301]}, {'slice': 30, 'patch_count': 0, 'bbox': [53, 309, 47, 303]}, {'slice': 31, 'patch_count': 0, 'bbox': [53, 309, 47, 303]}, {'slice': 32, 'patch_count': 0, 'bbox': [50, 306, 47, 303]}, {'slice': 33, 'patch_count': 0, 'bbox': [50, 306, 47, 303]}, {'slice': 34, 'patch_count': 0, 'bbox': [47, 303, 48, 304]}, {'slice': 35, 'patch_count': 0, 'bbox': [46, 302, 47, 303]}, {'slice': 35, 'patch_count': 1, 'bbox': [49, 305, 0, 256]}, {'slice': 36, 'patch_count': 0, 'bbox': [46, 302, 47, 303]}, {'slice': 36, 'patch_count': 1, 'bbox': [49, 305, 0, 256]}, {'slice': 37, 'patch_count': 0, 'bbox': [45, 301, 48, 304]}, {'slice': 37, 'patch_count': 1, 'bbox': [47, 303, 0, 256]}, {'slice': 38, 'patch_count': 0, 'bbox': [45, 301, 48, 304]}, {'slice': 38, 'patch_count': 1, 'bbox': [47, 303, 0, 256]}, {'slice': 39, 'patch_count': 0, 'bbox': [45, 301, 49, 305]}, {'slice': 39, 'patch_count': 1, 'bbox': [44, 300, 0, 256]}, {'slice': 40, 'patch_count': 0, 'bbox': [45, 301, 49, 305]}, {'slice': 40, 'patch_count': 1, 'bbox': [41, 297, 0, 256]}, {'slice': 41, 'patch_count': 0, 'bbox': [45, 301, 49, 305]}, {'slice': 41, 'patch_count': 1, 'bbox': [41, 297, 0, 256]}, {'slice': 42, 'patch_count': 0, 'bbox': [44, 300, 51, 307]}, {'slice': 42, 'patch_count': 1, 'bbox': [40, 296, 0, 256]}, {'slice': 43, 'patch_count': 0, 'bbox': [44, 300, 50, 306]}, {'slice': 43, 'patch_count': 1, 'bbox': [43, 299, 0, 256]}, {'slice': 44, 'patch_count': 0, 'bbox': [44, 300, 50, 306]}, {'slice': 44, 'patch_count': 1, 'bbox': [43, 299, 0, 256]}, {'slice': 45, 'patch_count': 0, 'bbox': [43, 299, 49, 305]}, {'slice': 45, 'patch_count': 1, 'bbox': [38, 294, 0, 256]}, {'slice': 46, 'patch_count': 0, 'bbox': [43, 299, 49, 305]}, {'slice': 46, 'patch_count': 1, 'bbox': [38, 294, 0, 256]}, {'slice': 47, 'patch_count': 0, 'bbox': [37, 293, 0, 256]}, {'slice': 47, 'patch_count': 1, 'bbox': [41, 297, 49, 305]}, {'slice': 48, 'patch_count': 0, 'bbox': [38, 294, 0, 256]}, {'slice': 48, 'patch_count': 1, 'bbox': [41, 297, 49, 305]}, {'slice': 49, 'patch_count': 0, 'bbox': [38, 294, 0, 256]}, {'slice': 49, 'patch_count': 1, 'bbox': [41, 297, 49, 305]}, {'slice': 50, 'patch_count': 0, 'bbox': [32, 288, 47, 303]}, {'slice': 51, 'patch_count': 0, 'bbox': [32, 288, 47, 303]}, {'slice': 52, 'patch_count': 0, 'bbox': [39, 295, 50, 306]}, {'slice': 53, 'patch_count': 0, 'bbox': [37, 293, 0, 256]}, {'slice': 54, 'patch_count': 0, 'bbox': [37, 293, 0, 256]}, {'slice': 55, 'patch_count': 0, 'bbox': [37, 293, 0, 256]}]

# %%
# --------------------------------------------------------- second network--------------------

crop_images, crop_masks = get_cube(torch.from_numpy(images_numpy).unsqueeze(dim=1),
                                   first_masks.unsqueeze(dim=1),crop_info)

print(crop_images.shape)
config.second_model = f"./ResNetUNet_sec_True_aug_Adam_0/CP_epoch16.pth"
model2 = ResNetUNet(in_channel=1, classes=4)
model2.load_state_dict(torch.load(config.first_model,
                                  map_location=config.device))
model2.to(device=config.device)
second_masks = validation.predict_all(model2, BaseDataset.preprocess(crop_images), config)
show_views(crop_images[39], crop_masks[39], second_masks[39], cmap="gray")
fina_masks = combine_image(second_masks, images_numpy.shape, crop_info)
show_views(images_numpy[39], ground_t[39], fina_masks[39], cmap="gray")
save.save_2_nii(fina_masks, save_path=config.save_path,
                patient_name="kidney")
# Out:
# torch.Size([256, 256]) torch.Size([206, 220]) 0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-ce94e123e68e> in <module>
#       1 # --------------------------------------------------------- second network--------------------
#       2
# ----> 3 crop_images, crop_masks = get_cube(torch.from_numpy(images_numpy).unsqueeze(dim=1),
#       4                                    first_masks.unsqueeze(dim=1),crop_info)
#       5
#
# ~/Study/git_pro/kits20_xcd/utils/validation.py in get_cube(image, mask, crop_info)
#     439         # print(info["slice"], bbox)
#     440         print(image_crop[index][0].shape, image[int(info["slice"])][0][bbox[0]:bbox[1], bbox[2]:bbox[3]].shape, index)
# --> 441         image_crop[index][0].add_(image[int(info["slice"])][0][bbox[0]:bbox[1], bbox[2]:bbox[3]])
#     442         mask_crop[index][0].add_(mask[int(info["slice"])][0][bbox[0]:bbox[1], bbox[2]:bbox[3]])
#     443
#
# RuntimeError: The size of tensor a (256) must match the size of tensor b (220) at non-singleton dimension 1
